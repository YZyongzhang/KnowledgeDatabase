# %%
import json
from DataImpl import Data_impl

# %%
test_json = {
    "key1":"dflja",
    "key2":"dfafff"
}
with open('./test.json' , 'w+') as f:
    json.dump(test_json , f)

# %%
data_imple = Data_impl(path='./test.json')

# %%
data_imple.get()
# Out:
# {'key1': 'dflja', 'key2': 'dfafff'}

# %%
data_imple.regex_keys(key="key1")
# Out:
# {'key1': 'dflja'}
